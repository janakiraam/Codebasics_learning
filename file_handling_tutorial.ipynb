# %% [markdown]
# ### Read the file line by line

# %%
class Pet:
    def __init__(self, name, sound):
        self.name = name
        self.sound = sound

    def speak(self):
        print(self.sound)

my_pet = Pet("Buster", "Woof")
my_pet.speak()
# Out:
# Woof

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.3-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.3-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB 262.6 kB/s eta 0:00:48
#    ---------------------------------------- 0.0/12.6 MB 262.6 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/12.6 MB 299.4 kB/s eta 0:00:42
#    ---------------------------------------- 0.1/12.6 MB 375.8 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/12.6 MB 386.4 kB/s eta 0:00:33
#    ---------------------------------------- 0.2/12.6 MB 437.1 kB/s eta 0:00:29
#     --------------------------------------- 0.2/12.6 MB 599.0 kB/s eta 0:00:21
#     --------------------------------------- 0.3/12.6 MB 583.8 kB/s eta 0:00:22
#    - -------------------------------------- 0.4/12.6 MB 791.2 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/12.6 MB 942.1 kB/s eta 0:00:13
#    - -------------------------------------- 0.6/12.6 MB 1.0 MB/s eta 0:00:12
#    -- ------------------------------------- 0.9/12.6 MB 1.6 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.6 MB 1.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.5/12.6 MB 2.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.6 MB 2.4 MB/s eta 0:00:05
#    ------- -------------------------------- 2.2/12.6 MB 2.8 MB/s eta 0:00:04
#    --------- ------------------------------ 3.1/12.6 MB 3.8 MB/s eta 0:00:03
#    ------------ --------------------------- 4.1/12.6 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.4/12.6 MB 4.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.6/12.6 MB 5.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.9/12.6 MB 6.8 MB/s eta 0:00:01
#    ------------------------ --------------- 7.8/12.6 MB 7.3 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 7.9 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 8.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.6/12.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 11.9/12.6 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.4.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
try:
    print(1/0)
except ZeroDivisionError:
    print("Cannot divide by zero.")
except Exception as e:
    print("Error occurred:", e)
# Out:
# Cannot divide by zero.

# %%
# read file
f=open("funny.txt","r")
for line in f:
    print(line)
f.close()
# Out:
# Teacher: Why are you late, raghu?
#
# Raghu: Because of the sign
#
# Teacher: What sign?
#
# Raghu: The one that says "School Ahead, Go slow"

# %% [markdown]
# In the above code you have to do f.close() to deallocate file resource. Sometimes a person may forget to do this. Python provides an easier method for this using with

# %% [markdown]
# ### with statement

# %%
with open("funny.txt","r") as f:
    for line in f:
        print(line)
# Out:
# Teacher: Why are you late, raghu?
#
# Raghu: Because of the sign
#
# Teacher: What sign?
#
# Raghu: The one that says "School Ahead, Go slow"

# %% [markdown]
# ### readlines

# %%
with open("funny.txt","r") as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['Teacher: Why are you late, raghu?\n', 'Raghu: Because of the sign\n', 'Teacher: What sign?\n', 'Raghu: The one that says "School Ahead, Go slow"']

# %% [markdown]
# ### write file

# %%
with open("love.txt","w") as f:
    f.write("I love python")

# %%
# same file when you write i love javascript the previous line goes away
with open("love.txt","w") as f:
    f.write("I love python")

# %%
# You can use append mode to stop having previous lines overwritten
with open("love.txt","a") as f:
    f.write("I love python")

# %%
# show a picture of file open modes (12:12 in old video)

# %% [markdown]
# ### writelines

# %%
with open("love.txt","w") as f:
    f.writelines(["I love C++\n","I love scala"])

# %% [markdown]
# ### sports data analytics

# %%
player_scores = {}

with open("scores.csv","r") as f:
    for line in f:
        player, _, score = line.split(",")
        score = int(score.strip())
        if player in player_scores:
            player_scores[player].append(score)
        else:
            player_scores[player] = [score]
            
player_scores
# Out:
# {'rohit': [9, 120, 105, 140, 130],
#  'shakib': [56, 78, 102, 72],
#  'babar': [56, 45, 120, 5, 67]}

# %%
for player, score_list in player_scores.items():
    min_score=min(score_list)
    max_score=max(score_list)
    avg_score=sum(score_list)/len(score_list)

    print(f"{player} ==> Min:{min_score}, Max:{max_score}, Avg:{avg_score}")
# Out:
# rohit ==> Min:9, Max:140, Avg:100.8
# shakib ==> Min:56, Max:102, Avg:77.0
# babar ==> Min:5, Max:120, Avg:58.6

# %% [markdown]
# ### remove file

# %%
with open("dummy.txt","w") as f:
    f.write("whatever")

# %%
import os
if os.path.exists("dummy.txt"):
    os.remove("dummy.txt")
else:
    print("file does not exist")
